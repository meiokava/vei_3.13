# %% [markdown]
# # Индивидуальное задание
# Найти контуры всеми способами
# 1. оператор Собеля
# 2. оператор Робертса
# 3. оператор Лапласа
# 4. алгоритм Кэнни

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image = cv2.imread('night.jpg', 0)

# %% [markdown]
# Применение оператора Собеля для обнаружения контуров

# %%
sobelx = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
sobely = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)
sobel = cv2.magnitude(sobelx, sobely)

# %% [markdown]
# Применение оператора Робертса для обнаружения контуров

# %%
ImageCopy = image.copy()

# %%
kernel_x = np.array([[1, 0], [0, -1]])
kernel_y = np.array([[0, 1], [-1, 0]])
gradient_x = cv2.filter2D(ImageCopy, cv2.CV_64F, kernel_x)
gradient_y = cv2.filter2D(ImageCopy, cv2.CV_64F, kernel_y)

# %%
gradient_abs = np.abs(gradient_x) + np.abs(gradient_y)
gradient_abs = np.uint8(gradient_abs)

# %%
threshold = 50
ret, roberts = cv2.threshold(gradient_abs, threshold, 255, cv2.THRESH_BINARY)

# %%
plt.figure(figsize=(20,20))
plt.subplot(132)
plt.imshow(image, cmap='gray')
plt.title('Original')
plt.xticks([])
plt.yticks([])

plt.subplot(133)
plt.imshow(roberts, cmap='gray')
plt.title('Roberts')
plt.xticks([])
plt.yticks([]);

plt.show()

# %% [markdown]
# Применение оператора Лапласа для обнаружения контуров

# %%
laplacian = cv2.Laplacian(image, cv2.CV_64F)

# %%
plt.figure(figsize=(20,20))
plt.subplot(132)
plt.imshow(image, cmap='gray')
plt.title('Original')
plt.xticks([])
plt.yticks([])

plt.subplot(133)
plt.imshow(sobel, cmap='gray')
plt.title('Sobel')
plt.xticks([])
plt.yticks([]);

plt.show()

# %%
canny = cv2.Canny(image,700,100,apertureSize = 3)

# %%
plt.figure(figsize=(20,20))

plt.subplot(131), plt.imshow(image, cmap='gray')
plt.title('Original')
plt.xticks([]), plt.yticks([])

plt.subplot(132)
plt.imshow(canny, cmap='gray')
plt.title('Canny')
plt.xticks([])
plt.yticks([])

plt.tight_layout()
plt.show()
